# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#lorenz curve
subsidies_series = pd.Series([856,560,395,311,285,203,199,179,168,157,147,142,132,124,117]) 
sorted_subsidies = subsidies_series.sort_values()
cumulative_subsidies = sorted_subsidies.cumsum()
cum_percentage = cumulative_subsidies/ subsidies_series.sum()

plt.figure(figsize=(8, 6))
plt.plot(cum_percentage, cumulative_subsidies / cumulative_subsidies.max(), marker='o', linestyle='-')

plt.plot([0, 0], [0, 0], color='gray', linestyle='--')


plt.title('Lorenz Curve of Subsidies Distribution')
plt.xlabel('Cumulative Population Percentage')
plt.ylabel('Cumulative Subsidies Percentage')


plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data
subsidies_series = pd.Series([856, 560, 395, 311, 285, 203, 199, 179, 168, 157, 147, 142, 132, 124, 117])

# Sort the data
sorted_subsidies = subsidies_series.sort_values()

# Calculate cumulative sum
cumulative_subsidies = sorted_subsidies.cumsum()

# Calculate cumulative percentages
cum_percentage_subsidies = cumulative_subsidies / cumulative_subsidies.max()
population_percentage = np.linspace(0, 1, len(sorted_subsidies))

# Plotting the Lorenz curve
plt.figure(figsize=(8, 6))
plt.plot(population_percentage, cum_percentage_subsidies, marker='o', linestyle='-', color='b', label='Lorenz Curve')

# Line of equality
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Line of Equality')

# Titles and labels
plt.title('Lorenz Curve of Subsidies Distribution')
plt.xlabel('Cumulative Population Percentage')
plt.ylabel('Cumulative Subsidies Percentage')
plt.legend()

# Grid
plt.grid(True)
plt.show()

# %%
s = pd.Series([856,560,395,311,285,203,199,179,168,157,147,142,132,124,117]) 
sorteds = s.sort_values(ascending=True)
sorteds
# Out:
# 14    117
# 13    124
# 12    132
# 11    142
# 10    147
# 9     157
# 8     168
# 7     179
# 6     199
# 5     203
# 4     285
# 3     311
# 2     395
# 1     560
# 0     856
# dtype: int64

# %%
sorteds.cumsum()
# Out:
# 14     117
# 13     241
# 12     373
# 11     515
# 10     662
# 9      819
# 8      987
# 7     1166
# 6     1365
# 5     1568
# 4     1853
# 3     2164
# 2     2559
# 1     3119
# 0     3975
# dtype: int64

# %%
suma = ((sorteds.cumsum()) * (sorteds.cumsum().rank())).sum()

# %%
(suma*2)/(15*s.sum()) - 16/15
# Out:
# 6.953895178197065

# %%
area = pd.Series([251313,320989,368026,393409,402522,439179,547496,570506,593280,647139,654885,683839,704306,760553,783152,796972]) 
areas = area.sort_values(ascending=True)
areas
# Out:
# 0     251313
# 1     320989
# 2     368026
# 3     393409
# 4     402522
# 5     439179
# 6     547496
# 7     570506
# 8     593280
# 9     647139
# 10    654885
# 11    683839
# 12    704306
# 13    760553
# 14    783152
# 15    796972
# dtype: int64

# %%
areas.cumsum()
# Out:
# 0      251313
# 1      572302
# 2      940328
# 3     1333737
# 4     1736259
# 5     2175438
# 6     2722934
# 7     3293440
# 8     3886720
# 9     4533859
# 10    5188744
# 11    5872583
# 12    6576889
# 13    7337442
# 14    8120594
# 15    8917566
# dtype: int64

# %%
summ = ((areas.cumsum()) * (areas.cumsum().rank())).sum()

# %%
(summ*2)/(16*area.sum()) - 17/16
# Out:
# 9.27207154956857

# %%
income = pd.read_excel('D:\LabHw\DescriptiveStat\data\incomeRF_data.xlsx')
income.columns
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13328\1289330469.py:1: SyntaxWarning: invalid escape sequence '\L'
#   income = pd.read_excel('D:\LabHw\DescriptiveStat\data\incomeRF_data.xlsx')
# Index(['income', 'sex', 'family.size', 'urbanity', 'province', 'AP.income',
#        'AP.family.size', 'AP.weight'],
#       dtype='object')

# %%
income['province']
# Out:
# 0      Ilocos Norte
# 1      Ilocos Norte
# 2      Ilocos Norte
# 3      Ilocos Norte
# 4      Ilocos Norte
#            ...
# 627      Pangasinan
# 628      Pangasinan
# 629      Pangasinan
# 630      Pangasinan
# 631      Pangasinan
# Name: province, Length: 632, dtype: object
